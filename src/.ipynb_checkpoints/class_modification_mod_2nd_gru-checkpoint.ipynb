# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
from model_mod import *

# %%
BATCH_SIZE = 256

# %%
path_to_zip = tf.keras.utils.get_file(
    'spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip',
    extract=True)

path_to_file = os.path.dirname(path_to_zip)+"/spa-eng/spa.txt"

en_sentence = u"May I borrow this book?"
sp_sentence = u"¿Puedo tomar prestado este libro?"
print(preprocess_sentence(en_sentence))
print(preprocess_sentence(sp_sentence).encode('utf-8'))

en, sp = create_dataset(path_to_file, None)
print(en[-1])
print(sp[-1])

# Try experimenting with the size of that dataset
# num_examples = 118964
num_examples = 30000

input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)
# Out:
# <start> may i borrow this book ? <end>
# b'<start> \xc2\xbf puedo tomar prestado este libro ? <end>'
# <start> if you want to sound like a native speaker , you must be willing to practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo . <end>
# <start> si quieres sonar como un hablante nativo , debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un musico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado . <end>

# %%
# input_tensor = input_tensor[-30000:, :]
# target_tensor = target_tensor[-30000:, :]

# %%
# Calculate max_length of the target tensors
max_length_targ, max_length_inp = max_length(target_tensor), max_length(input_tensor)

# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

BUFFER_SIZE = len(input_tensor_train)
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

# %%
my_model = NMT((vocab_inp_size, vocab_tar_size), inp_lang, targ_lang)

# %%
EPOCHS = 45

for epoch in range(EPOCHS):

    start = time.time()

    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch += 1
        batch_loss = my_model.train(inp, targ)
        total_loss += batch_loss
        
#         if batch % 150 == 0:
#             print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
#                                                          batch,
#                                                          batch_loss.numpy()))
#             print('Time taken for 1 batch {:.1f} sec\n'.format(time.time() - start))

    print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                  total_loss / steps_per_epoch))
    print('Time taken for an epoch: {:.1f} sec\n'.format(time.time() - start))
    
#     my_model.translate(u'hace mucho frio aqui.', max_length_targ, max_length_inp)

    
    if (epoch + 1) % 15 == 0:
        my_model.translate(u'hace mucho frio aqui.', max_length_targ, max_length_inp)
# Out:
# Epoch 1 Loss 2.9694
# Time taken for an epoch: 27.8 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i <end>
# Epoch 2 Loss 2.4731
# Time taken for an epoch: 26.8 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i i i . <end>
# Epoch 3 Loss 2.3404
# Time taken for an epoch: 27.8 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i i i i you . <end>
# Epoch 4 Loss 2.2375
# Time taken for an epoch: 27.6 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i i is . <end>
# Epoch 5 Loss 2.1422
# Time taken for an epoch: 25.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i is a . <end>
# Epoch 6 Loss 2.0849
# Time taken for an epoch: 25.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i is a . <end>
# Epoch 7 Loss 2.0449
# Time taken for an epoch: 25.6 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i s you t t you a . <end>
# Epoch 8 Loss 2.0183
# Time taken for an epoch: 25.8 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i s a a . <end>
# Epoch 9 Loss 1.9938
# Time taken for an epoch: 26.0 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i s a . <end>
# Epoch 10 Loss 1.9726
# Time taken for an epoch: 26.5 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i s a . <end>
# Epoch 11 Loss 1.9527
# Time taken for an epoch: 26.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m a . <end>
# Epoch 12 Loss 1.9266
# Time taken for an epoch: 27.8 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m a a me a . <end>
# Epoch 13 Loss 1.9027
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m a me a . <end>
# Epoch 14 Loss 1.8753
# Time taken for an epoch: 27.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m a me a . <end>
# Epoch 15 Loss 1.8509
# Time taken for an epoch: 27.8 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m a . . <end>
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m a . . <end>
# Epoch 16 Loss 1.8185
# Time taken for an epoch: 27.8 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m a . . <end>
# Epoch 17 Loss 1.7762
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m a . . <end>
# Epoch 18 Loss 1.7342
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m not a . . <end>
# Epoch 19 Loss 1.6930
# Time taken for an epoch: 27.0 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m not a . <end>
# Epoch 20 Loss 1.6336
# Time taken for an epoch: 27.4 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: i m not a car . <end>
# Epoch 21 Loss 1.5708
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: tom s not a car . <end>
# Epoch 22 Loss 1.5137
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: tom s not a car . <end>
# Epoch 23 Loss 1.4576
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: he s a good . <end>
# Epoch 24 Loss 1.4012
# Time taken for an epoch: 27.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: you re a car . <end>
# Epoch 25 Loss 1.3444
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: you re a car . <end>
# Epoch 26 Loss 1.2886
# Time taken for an epoch: 27.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s a car . <end>
# Epoch 27 Loss 1.2289
# Time taken for an epoch: 27.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s a good car . <end>
# Epoch 28 Loss 1.1647
# Time taken for an epoch: 27.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s a good today . <end>
# Epoch 29 Loss 1.1036
# Time taken for an epoch: 27.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 30 Loss 1.0442
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 31 Loss 0.9862
# Time taken for an epoch: 27.3 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 32 Loss 0.9290
# Time taken for an epoch: 26.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 33 Loss 0.8734
# Time taken for an epoch: 26.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 34 Loss 0.8190
# Time taken for an epoch: 27.3 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 35 Loss 0.7693
# Time taken for an epoch: 27.5 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 36 Loss 0.7198
# Time taken for an epoch: 26.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 37 Loss 0.6736
# Time taken for an epoch: 27.1 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 38 Loss 0.6318
# Time taken for an epoch: 26.5 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too good here . <end>
# Epoch 39 Loss 0.5938
# Time taken for an epoch: 26.4 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too happy here . <end>
# Epoch 40 Loss 0.5534
# Time taken for an epoch: 26.4 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too happy here . <end>
# Epoch 41 Loss 0.5084
# Time taken for an epoch: 26.6 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too happy here . <end>
# Epoch 42 Loss 0.4693
# Time taken for an epoch: 27.7 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too happy here . <end>
# Epoch 43 Loss 0.4359
# Time taken for an epoch: 26.0 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too cold here . <end>
# Epoch 44 Loss 0.4067
# Time taken for an epoch: 26.1 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too cold here . <end>
# Epoch 45 Loss 0.3803
# Time taken for an epoch: 25.9 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too happy here . <end>
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too happy here . <end>

# %%
my_model.translate(u'hace mucho frio aqui.', max_length_targ, max_length_inp)
# Out:
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: it s too happy here . <end>

# %%
my_model.translate(u'esta es mi vida.', max_length_targ, max_length_inp)
# Out:
# Input: <start> esta es mi vida . <end>
# Predicted translation: this is my life . <end>

# %%
my_model.translate(u'¿todavia estan en casa?', max_length_targ, max_length_inp)
# Out:
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: are you still home ? <end>

# %%
# wrong translation
my_model.translate(u'¿Hay algún problema que pueda ayudar?', max_length_targ, max_length_inp)
# Out:
# Input: <start> ¿ hay algun problema que pueda ayudar ? <end>
# Predicted translation: is anybody really mother ? <end>
