# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

from model import *
import model2

BATCH_SIZE = 512
embedding_dim = 256
units = 128

path_to_zip = tf.keras.utils.get_file(
    'spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip',
    extract=True)

path_to_file = os.path.dirname(path_to_zip)+"/spa-eng/spa.txt"

en_sentence = u"May I borrow this book?"
sp_sentence = u"¿Puedo tomar prestado este libro?"
print(preprocess_sentence(en_sentence))
print(preprocess_sentence(sp_sentence).encode('utf-8'))

en, sp = create_dataset(path_to_file, None)
print(en[-1])
print(sp[-1])

# Try experimenting with the size of that dataset
num_examples = 118964
# num_examples = 30000

input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = max_length(target_tensor), max_length(input_tensor)

# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

BUFFER_SIZE = len(input_tensor_train)
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1
# Out:
# <start> may i borrow this book ? <end>
# b'<start> \xc2\xbf puedo tomar prestado este libro ? <end>'
# <start> if you want to sound like a native speaker , you must be willing to practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo . <end>
# <start> si quieres sonar como un hablante nativo , debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un musico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado . <end>

# %%
my_model2 = model2.GNMT((256, 256), (128, 128), inp_lang, targ_lang)

# %%
EPOCHS = 1

for epoch in range(EPOCHS):

    start = time.time()

    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):        
        batch_loss = my_model2.train(inp, targ)
        total_loss += batch_loss
        
#         if batch % 50 == 0:
#             print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
#                                                          batch,
#                                                          batch_loss.numpy()))
#             print('Time taken for 1 batch {:.1f} sec\n'.format(time.time() - start))

    print('Epoch {} Loss {:.4f}'.format(epoch + 1, total_loss / steps_per_epoch))
    print('Time taken for an epoch: {:.1f} sec\n'.format(time.time() - start))
        
    my_model2.translate(u'hace mucho frio aqui.', max_length_targ)
# Out:
# Epoch 1 Loss 1.7685
# Time taken for an epoch: 956.4 sec
#
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE NONE

# %%
EPOCHS = 100

for epoch in range(EPOCHS):

    start = time.time()

    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):        
        batch_loss = my_model2.train(inp, targ)
        total_loss += batch_loss
        
#         if batch % 50 == 0:
#             print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
#                                                          batch,
#                                                          batch_loss.numpy()))
#             print('Time taken for 1 batch {:.1f} sec\n'.format(time.time() - start))

    print('Epoch {} Loss {:.4f}'.format(epoch + 1, total_loss / steps_per_epoch))
    print('Time taken for an epoch: {:.1f} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Loss 1.7663
# Time taken for an epoch: 156.5 sec
#
# Epoch 2 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 3 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 4 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 5 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 6 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 7 Loss 1.7663
# Time taken for an epoch: 155.7 sec
#
# Epoch 8 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 9 Loss 1.7663
# Time taken for an epoch: 157.1 sec
#
# Epoch 10 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 11 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 12 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 13 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 14 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 15 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 16 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 17 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 18 Loss 1.7663
# Time taken for an epoch: 156.5 sec
#
# Epoch 19 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 20 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 21 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 22 Loss 1.7663
# Time taken for an epoch: 156.5 sec
#
# Epoch 23 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 24 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 25 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 26 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 27 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 28 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 29 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 30 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 31 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 32 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 33 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 34 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 35 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 36 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 37 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 38 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 39 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 40 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 41 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 42 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 43 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 44 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 45 Loss 1.7663
# Time taken for an epoch: 156.7 sec
#
# Epoch 46 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 47 Loss 1.7663
# Time taken for an epoch: 156.9 sec
#
# Epoch 48 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 49 Loss 1.7663
# Time taken for an epoch: 156.5 sec
#
# Epoch 50 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 51 Loss 1.7663
# Time taken for an epoch: 156.5 sec
#
# Epoch 52 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 53 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 54 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 55 Loss 1.7663
# Time taken for an epoch: 156.7 sec
#
# Epoch 56 Loss 1.7663
# Time taken for an epoch: 156.5 sec
#
# Epoch 57 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 58 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 59 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 60 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 61 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 62 Loss 1.7663
# Time taken for an epoch: 156.6 sec
#
# Epoch 63 Loss 1.7663
# Time taken for an epoch: 156.5 sec
#
# Epoch 64 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 65 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 66 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 67 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 68 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 69 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 70 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 71 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 72 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 73 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 74 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 75 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 76 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 77 Loss 1.7663
# Time taken for an epoch: 155.8 sec
#
# Epoch 78 Loss 1.7663
# Time taken for an epoch: 156.4 sec
#
# Epoch 79 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 80 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 81 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 82 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 83 Loss 1.7663
# Time taken for an epoch: 155.9 sec
#
# Epoch 84 Loss 1.7663
# Time taken for an epoch: 155.9 sec
#
# Epoch 85 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 86 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 87 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 88 Loss 1.7663
# Time taken for an epoch: 156.3 sec
#
# Epoch 89 Loss 1.7663
# Time taken for an epoch: 156.2 sec
#
# Epoch 90 Loss 1.7663
# Time taken for an epoch: 156.5 sec
#
# Epoch 91 Loss 1.7663
# Time taken for an epoch: 156.1 sec
#
# Epoch 92 Loss 1.7663
# Time taken for an epoch: 156.0 sec
#
# Epoch 93 Loss 1.7663
# Time taken for an epoch: 155.8 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4379a5cd50e3> in <module>
#       8
#       9     for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
# ---> 10         batch_loss = my_model2.train(inp, targ)
#      11         total_loss += batch_loss
#      12
#
# c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     402       # In this case we have created variables on the first call, so we run the
#     403       # defunned version which is guaranteed to never create variables.
# --> 404       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     405     elif self._stateful_fn is not None:
#     406       # In this case we have not created variables on the first call. So we can
#
# c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    1333     """Calls a graph function specialized to the inputs."""
#    1334     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1335     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1336
#    1337   @property
#
# c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#     587     """
#     588     return self._call_flat(
# --> 589         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#     590          if isinstance(t, (ops.Tensor,
#     591                            resource_variable_ops.ResourceVariable))))
#
# c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args)
#     669     # Only need to override the gradient in graph mode and when we have outputs.
#     670     if context.executing_eagerly() or not self.outputs:
# --> 671       outputs = self._inference_function.call(ctx, args)
#     672     else:
#     673       self._register_gradient()
#
# c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args)
#     443             attrs=("executor_type", executor_type,
#     444                    "config_proto", config),
# --> 445             ctx=ctx)
#     446       # Replace empty list with None
#     447       outputs = outputs or None
#
# c:\users\jw\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
my_model2.target_tokenizer.index_word

# %%
my_model.translate(u'hace mucho frio aqui.', max_length_targ, max_length_inp)

# %%
my_model.translate(u'esta es mi vida.', max_length_targ, max_length_inp)

# %%
my_model.translate(u'¿todavia estan en casa?', max_length_targ, max_length_inp)

# %%
# wrong translation
my_model.translate(u'¿Hay algún problema que pueda ayudar?', max_length_targ, max_length_inp)
